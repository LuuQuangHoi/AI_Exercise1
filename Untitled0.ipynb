# %% [markdown]
# <a href="https://colab.research.google.com/github/LuuQuangHoi/AI_Exercise1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt',mode ='w') as accounts:
  accounts.write('20146124 Luu Quang Hoi   8.0\n')
  accounts.write('20146125 Luu Quang A   8.0\n')
  accounts.write('20146126 Luu Quang B   8.0\n')
  accounts.write('20146127 Luu Quang C   8.0\n')
  accounts.write('20146128 Luu Quang D   8.0\n')

# %%
with open('text1.txt',mode='r') as accounts:
  print(f'{" MSSV":<10}{"Name":<20}{"Score":>4}')
  for record in accounts:
    mssv,name,score=record.split()
    print(f'{mssv:<10}{name:<20}{score:>4}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9517984d2ad5> in <module>
# ----> 1 with open('text1.txt',mode='r') as accounts:
#       2   print(f'{" MSSV":<10}{"Name":<20}{"Score":>4}')
#       3   for record in accounts:
#       4     mssv,name,score=record.split()
#       5     print(f'{mssv:<10}{name:<20}{score:>4}')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text1.txt'

# %% [markdown]
# # New Section

# %%
import pandas as pd
url = 'text2.csv'
dataframe = pd.read_csv(url)
dataframe.head(20)
#dataframe.shape
#dataframe.describe()
dataframe.iloc[10]
dataframe.iloc[:4]
# Out:
#        MSSV      Ho va ten Khóa Khoa  Điểm
# 0  20146124  Luu Quang Hoi  K20  CKM   8.0
# 1  19146125   Nguyen Van A  K19  CKM   9.0
# 2  20146126   Nguyen Van B  K20  CKM   7.0
# 3  20146127   Nguyen Van C  K20  CKM   8.0

# %%
dataframe.iloc[:4]

# %%
dataframe.iloc[0:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5dc03f24c490> in <module>
# ----> 1 dataframe.iloc[0:4]
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.iloc[10]

# %%
frame = dataframe.set_index(dataframe['Ho va ten'])
frame.loc['Nguyen Van A']

# %%
dataframe[dataframe['Khoa']=='CKM'].head(5)

# %%
dataframe[dataframe['Ho va ten']=='Nguyen Van B'].head(5)

# %%
dataframe[dataframe['Ho va ten']=='Le Van B'].head(5)

# %%
dataframe[(dataframe['Khoa']=='CKM')&(dataframe['Khóa']=='K19')]

# %%
dataframe[(dataframe['Khoa']=='CKM')&(dataframe['Điểm']==5.6)]

# %%
dataframe[(dataframe['Khoa']=='CKM')&(dataframe['MSSV']==20146123)]

# %%
dataframe[(dataframe['Khoa']=='CKM')&(dataframe['Điểm']>8)]

# %%
dataframe[(dataframe['Khoa']=='CKM') & (dataframe['Điểm']>9)]

# %%
dataframe['Điểm'].min()

# %%
dataframe['Điểm'].mean()

# %%
dataframe['Điểm'].count()

# %%
dataframe['Khoa'].unique()

# %%
dataframe['Khoa'].value_counts()

# %%
dataframe['Khóa'].unique()

# %%
dataframe.drop('Khoa',axis=1).head(5)

# %%
dataframe.drop(['Khoa','Khóa'],axis=1).head(5)

# %%
dataframe.drop(dataframe.columns[2:4],axis =1).head(5)

# %%
dataframe.head(10)

# %%
dataframe.drop(dataframe.columns[2:4],axis =1).head(5)

# %%
dataframe[dataframe['Khóa']!= 'K19'].head(20)

# %%
dataframe[dataframe['Khoa']!= 'CKM'].head(20)

# %%
dataframe[dataframe.index!=4].head(20)
# Out:
#         MSSV      Ho va ten Khóa Khoa  Điểm
# 0   20146124  Luu Quang Hoi  K20  CKM   8.0
# 1   19146125   Nguyen Van A  K19  CKM   9.0
# 2   20146126   Nguyen Van B  K20  CKM   7.0
# 3   20146127   Nguyen Van C  K20  CKM   8.0
# 5   20146129   Nguyen Van E  K20  CKM   9.0
# 6   20146130   Nguyen Van F  K20  CKM   7.6
# 7   20146131   Nguyen Van G  K20  CKM   8.2
# 8   20146132   Nguyen Van H  K19  CKM   6.3
# 9   20146133   Nguyen Van I  K20  CKM   7.8
# 10  20146134   Nguyen Van K  K20  CKM   9.4
# 11  20146135   Nguyen Van L  K20  CKM   5.6
# 12  20146136   Nguyen Van M  K20  CKM   8.7

# %%
dataframe.groupby('Khóa').head(15)

# %%
dataframe.groupby('Khóa').count()

# %%
dataframe.groupby(['Khóa','Khoa']).head(20)

# %%
dataframe.groupby(['Khóa','Khoa']).count()

# %%
dataframe.groupby(['Khóa','Khoa'])['Điểm'].count()

# %%
dataframe.groupby('Khóa').head(15)
dataframe.groupby('Khóa').count()

# %%
import numpy as np
import pandas as pd

time = pd.date_range('01/01/2023',periods = 100000, freq = '30s')
dataframe = pd.DataFrame(index = time)
dataframe['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('W').sum()

# %%
chọn 1 nước lọc dữ liệu huy chương từ các môn

# %%
data[data['City']=='Chamonix'].head(50)

# %%
import pandas as pd
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data[(data['City']=='Oslo')&(data['Medal']=='Gold')]
# Out:
#      Year  City       Sport       Discipline  NOC                 Event  \
# 254  1952  Oslo      Skiing    Alpine Skiing  AUT              downhill
# 258  1952  Oslo      Skiing    Alpine Skiing  AUT                slalom
# 259  1952  Oslo  Ice Hockey       Ice Hockey  CAN            ice hockey
# 262  1952  Oslo      Skiing  Cross Country S  FIN                  10km
# 266  1952  Oslo      Skiing  Cross Country S  FIN          4x10km relay
# 267  1952  Oslo      Skiing  Cross Country S  FIN                  50km
# 271  1952  Oslo   Bobsleigh        Bobsleigh  FRG              four-man
# 272  1952  Oslo   Bobsleigh        Bobsleigh  FRG               two-man
# 273  1952  Oslo     Skating   Figure skating  GBR            individual
# 274  1952  Oslo     Skating   Figure skating  GER                 pairs
# 280  1952  Oslo      Skiing    Alpine Skiing  ITA              downhill
# 285  1952  Oslo     Skating    Speed skating  NOR                10000m
# ...

# %%
data[(data['City']=='Oslo')&(data['Medal']=='Silver')]
# Out:
#      Year  City       Sport       Discipline  NOC                 Event  \
# 251  1952  Oslo     Skating   Figure skating  AUT            individual
# 253  1952  Oslo      Skiing    Alpine Skiing  AUT              downhill
# 256  1952  Oslo      Skiing    Alpine Skiing  AUT          giant slalom
# 257  1952  Oslo      Skiing    Alpine Skiing  AUT          giant slalom
# 263  1952  Oslo      Skiing  Cross Country S  FIN                  10km
# 265  1952  Oslo      Skiing  Cross Country S  FIN                  18km
# 268  1952  Oslo      Skiing  Cross Country S  FIN                  50km
# 269  1952  Oslo      Skiing  Nordic Combined  FIN            individual
# 275  1952  Oslo      Skiing    Alpine Skiing  GER              downhill
# 278  1952  Oslo      Skiing    Alpine Skiing  GER                slalom
# 282  1952  Oslo     Skating    Speed skating  NED                10000m
# 283  1952  Oslo     Skating    Speed skating  NED                 1500m
# ...

# %%
data[(data['City']=='Oslo')&(data['Medal']=='Bronze')]
# Out:
#      Year  City       Sport       Discipline  NOC                 Event  \
# 252  1952  Oslo      Skiing    Alpine Skiing  AUT              downhill
# 255  1952  Oslo      Skiing    Alpine Skiing  AUT          giant slalom
# 260  1952  Oslo     Skating    Speed skating  CAN                  500m
# 261  1952  Oslo      Skiing  Cross Country S  FIN                  10km
# 264  1952  Oslo      Skiing  Cross Country S  FIN                  18km
# 270  1952  Oslo     Skating   Figure skating  FRA            individual
# 276  1952  Oslo      Skiing    Alpine Skiing  GER          giant slalom
# 277  1952  Oslo      Skiing    Alpine Skiing  GER                slalom
# 279  1952  Oslo     Skating   Figure skating  HUN                 pairs
# 281  1952  Oslo      Skiing    Alpine Skiing  ITA              downhill
# 286  1952  Oslo     Skating    Speed skating  NOR                 1500m
# 288  1952  Oslo     Skating    Speed skating  NOR                 5000m
# ...
